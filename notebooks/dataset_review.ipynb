# %%
import polars as pl

backtranslate_df = pl.read_parquet(
    "../dataset_files/gutenberg_summary_continuation.parquet"
)

# %%
from IPython.display import Markdown
for row in backtranslate_df.to_dicts():
    print(row.keys())
    display(Markdown(row['prefix']))
    display(Markdown(row['summary_content']))
    display(Markdown(row['summary']))
