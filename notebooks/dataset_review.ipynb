# %%
import polars as pl

backtranslate_df = pl.read_parquet(
    "../dataset_files/epubs.parquet"
)

# %%
backtranslate_df
# Out:
# shape: (17, 2)
# ┌─────────────────────────────────┬─────────────────────────────────┐
# │ title                           ┆ text                            │
# │ ---                             ┆ ---                             │
# │ str                             ┆ str                             │
# ╞═════════════════════════════════╪═════════════════════════════════╡
# │ EPUB publication.epub           ┆ A Mystery Reader 001: Short St… │
# │ A Mystery Reader Short Stories… ┆ A Mystery Reader 001: Short St… │
# │ 9781541071735(1).epub           ┆ []                              │
# │                                 ┆                                 │
# │                                 ┆ [Image]                         │
# │                                 ┆                                 │
# │                                 ┆ Dedicated to Robe…              │
# │ EPUB publication 3.epub         ┆ []                              │
# ...
